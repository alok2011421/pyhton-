# %%
#Option Choice
print("What would you like to have?")
print("1.espresso\n2.latte\n3.cappuccino")
a=int(input())

# %%
#turning of the machine
while True:
 b=input()
 if b=="OFF":
     break
 else:
     continue
